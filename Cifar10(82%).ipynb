# %%
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import Activation
from tensorflow.python.framework import ops
ops.reset_default_graph()
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.datasets import cifar10
from keras.layers import Dense
import tensorflow_hub as hub
from keras.layers import Dropout
from keras.layers import BatchNormalization
import numpy as np
import matplotlib.pyplot as plt
import math
from keras_preprocessing.image import ImageDataGenerator
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0523 13:09:01.759592 140477577840512 __init__.py:56] Some hub symbols are not available because TensorFlow version is less than 1.14

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print("x_train shape:", x_train.shape, "y_train shape:", y_train.shape)
# Out:
# x_train shape: (50000, 32, 32, 3) y_train shape: (50000, 1)

# %%
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# %%
num_classes=10
epochs=50
batch_size=128

img_height,img_width,channel= x_train.shape[1],x_train.shape[2],x_train.shape[3]

# %%
# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
model = Sequential([
    Conv2D(64, (3, 3),input_shape=(img_height,img_width,channel), padding='same',
           activation='relu'),
    Conv2D(64, (3, 3), activation='relu', padding='same'),
    MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),BatchNormalization(),
    Conv2D(128, (3, 3), activation='relu', padding='same'),
    Conv2D(128, (3, 3), activation='relu', padding='same',),
    MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),BatchNormalization(),
    Conv2D(256, (3, 3), activation='relu', padding='same',),
    Conv2D(256, (3, 3), activation='relu', padding='same',),
    Conv2D(256, (3, 3), activation='relu', padding='same',),
    MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),BatchNormalization(),
    Conv2D(512, (3, 3), activation='relu', padding='same',),
    Conv2D(512, (3, 3), activation='relu', padding='same',),
    Conv2D(512, (3, 3), activation='relu', padding='same',),
    MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),BatchNormalization(),
    Conv2D(512, (3, 3), activation='relu', padding='same',),
    Conv2D(512, (3, 3), activation='relu', padding='same',),
    Conv2D(512, (3, 3), activation='relu', padding='same',),
    MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),
    Flatten(),
    Dense(4096, activation='relu'),
    Dense(4096, activation='relu'),
    Dense(num_classes,activation='softmax')
])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        1792
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 4, 4, 256)         1024
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 4, 4, 512)         1180160
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 4, 4, 512)         2359808
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 4, 4, 512)         2359808
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 2, 2, 512)         2048
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 2, 2, 512)         2359808
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 2, 2, 512)         2359808
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 2, 2, 512)         2359808
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              2101248
# _________________________________________________________________
# dense_2 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                40970
# =================================================================
# Total params: 33,642,058
# Trainable params: 33,640,138
# Non-trainable params: 1,920
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
datagen =ImageDataGenerator( 
                    rotation_range=45, 
                    width_shift_range=.15, 
                    height_shift_range=.15, 
                    horizontal_flip=True, 
                    vertical_flip=True
#                     zoom_range=0.5
                    )

datagen.fit(x_train)

model.fit_generator(datagen.flow(x_train, y_train, batch_size=128),
                    steps_per_epoch=len(x_train) / 128, epochs=epochs,validation_data=(x_test,y_test))
# Out:
# Epoch 1/50
# 391/390 [==============================] - 53s 135ms/step - loss: 1.3544 - acc: 0.5322 - val_loss: 0.8696 - val_acc: 0.7085
# Epoch 2/50
# 391/390 [==============================] - 52s 134ms/step - loss: 1.0816 - acc: 0.6248 - val_loss: 0.9247 - val_acc: 0.6992
# Epoch 3/50
# 391/390 [==============================] - 52s 134ms/step - loss: 0.9759 - acc: 0.6657 - val_loss: 0.8639 - val_acc: 0.7113
# Epoch 4/50
# 391/390 [==============================] - 52s 134ms/step - loss: 0.9265 - acc: 0.6828 - val_loss: 1.1278 - val_acc: 0.6671
# Epoch 5/50
# 391/390 [==============================] - 47s 120ms/step - loss: 0.8731 - acc: 0.7018 - val_loss: 0.7359 - val_acc: 0.7561
# Epoch 6/50
# 391/390 [==============================] - 50s 127ms/step - loss: 0.8307 - acc: 0.7159 - val_loss: 0.8276 - val_acc: 0.7436
# Epoch 7/50
# 391/390 [==============================] - 49s 125ms/step - loss: 0.7977 - acc: 0.7282 - val_loss: 0.8419 - val_acc: 0.7197
# Epoch 8/50
# 391/390 [==============================] - 50s 128ms/step - loss: 0.7674 - acc: 0.7391 - val_loss: 0.6635 - val_acc: 0.7787
# Epoch 9/50
# 391/390 [==============================] - 35s 90ms/step - loss: 0.7347 - acc: 0.7477 - val_loss: 0.6971 - val_acc: 0.7684
# Epoch 10/50
# 391/390 [==============================] - 47s 120ms/step - loss: 0.7221 - acc: 0.7546 - val_loss: 0.6616 - val_acc: 0.7778
# Epoch 11/50
# 391/390 [==============================] - 49s 125ms/step - loss: 0.7033 - acc: 0.7618 - val_loss: 0.6845 - val_acc: 0.7748
# Epoch 12/50
# 391/390 [==============================] - 48s 123ms/step - loss: 0.6814 - acc: 0.7669 - val_loss: 0.6463 - val_acc: 0.7847
# Epoch 13/50
# 391/390 [==============================] - 50s 129ms/step - loss: 0.6645 - acc: 0.7734 - val_loss: 0.6508 - val_acc: 0.7871
# Epoch 14/50
# 391/390 [==============================] - 48s 122ms/step - loss: 0.6472 - acc: 0.7797 - val_loss: 0.7515 - val_acc: 0.7576
# Epoch 15/50
# 391/390 [==============================] - 49s 126ms/step - loss: 0.6271 - acc: 0.7871 - val_loss: 0.6864 - val_acc: 0.7814
# Epoch 16/50
# 391/390 [==============================] - 49s 125ms/step - loss: 0.6135 - acc: 0.7920 - val_loss: 0.6551 - val_acc: 0.7807
# Epoch 17/50
# 391/390 [==============================] - 50s 129ms/step - loss: 0.6043 - acc: 0.7955 - val_loss: 0.6981 - val_acc: 0.7730
# Epoch 18/50
# 391/390 [==============================] - 50s 128ms/step - loss: 0.5966 - acc: 0.7958 - val_loss: 0.6459 - val_acc: 0.7919
# Epoch 19/50
# 391/390 [==============================] - 50s 128ms/step - loss: 0.5842 - acc: 0.8016 - val_loss: 0.6036 - val_acc: 0.7983
# Epoch 20/50
# 391/390 [==============================] - 51s 131ms/step - loss: 0.5687 - acc: 0.8071 - val_loss: 0.5610 - val_acc: 0.8115
# Epoch 21/50
# 391/390 [==============================] - 52s 133ms/step - loss: 0.5512 - acc: 0.8115 - val_loss: 0.5939 - val_acc: 0.8051
# Epoch 22/50
# 391/390 [==============================] - 49s 126ms/step - loss: 0.5496 - acc: 0.8135 - val_loss: 0.5430 - val_acc: 0.8213
# Epoch 23/50
# 391/390 [==============================] - 51s 131ms/step - loss: 0.5375 - acc: 0.8183 - val_loss: 0.6584 - val_acc: 0.7865
# Epoch 24/50
# 391/390 [==============================] - 49s 126ms/step - loss: 0.5240 - acc: 0.8233 - val_loss: 0.5855 - val_acc: 0.8094
# Epoch 25/50
# 391/390 [==============================] - 48s 123ms/step - loss: 0.5165 - acc: 0.8242 - val_loss: 0.6096 - val_acc: 0.8067
# Epoch 26/50
# 391/390 [==============================] - 50s 127ms/step - loss: 0.5132 - acc: 0.8261 - val_loss: 0.5559 - val_acc: 0.8181
# Epoch 27/50
# 391/390 [==============================] - 47s 121ms/step - loss: 0.4968 - acc: 0.8314 - val_loss: 0.5731 - val_acc: 0.8181
# Epoch 28/50
# 391/390 [==============================] - 51s 130ms/step - loss: 0.4946 - acc: 0.8306 - val_loss: 0.5263 - val_acc: 0.8233
# Epoch 29/50
# 391/390 [==============================] - 52s 133ms/step - loss: 0.4883 - acc: 0.8331 - val_loss: 0.6369 - val_acc: 0.7923
# Epoch 30/50
# 391/390 [==============================] - 48s 123ms/step - loss: 0.4774 - acc: 0.8388 - val_loss: 0.5503 - val_acc: 0.8232
# Epoch 31/50
# 391/390 [==============================] - 50s 128ms/step - loss: 0.4682 - acc: 0.8412 - val_loss: 0.5111 - val_acc: 0.8293
# Epoch 32/50
# 391/390 [==============================] - 48s 123ms/step - loss: 0.4689 - acc: 0.8409 - val_loss: 0.5798 - val_acc: 0.8107
# Epoch 33/50
# 391/390 [==============================] - 49s 124ms/step - loss: 0.4601 - acc: 0.8444 - val_loss: 0.5262 - val_acc: 0.8235
# Epoch 34/50
# 391/390 [==============================] - 49s 127ms/step - loss: 0.4470 - acc: 0.8493 - val_loss: 0.5450 - val_acc: 0.8242
# Epoch 35/50
# 391/390 [==============================] - 49s 125ms/step - loss: 0.4443 - acc: 0.8507 - val_loss: 0.5795 - val_acc: 0.8172
# Epoch 36/50
# 391/390 [==============================] - 50s 129ms/step - loss: 0.4457 - acc: 0.8482 - val_loss: 0.6545 - val_acc: 0.7873
# Epoch 37/50
# 391/390 [==============================] - 48s 124ms/step - loss: 0.4379 - acc: 0.8526 - val_loss: 0.5001 - val_acc: 0.8362
# Epoch 38/50
# 391/390 [==============================] - 49s 125ms/step - loss: 0.4282 - acc: 0.8537 - val_loss: 0.5441 - val_acc: 0.8226
# Epoch 39/50
# 391/390 [==============================] - 51s 129ms/step - loss: 0.4242 - acc: 0.8548 - val_loss: 0.5579 - val_acc: 0.8185
# Epoch 40/50
# 391/390 [==============================] - 49s 125ms/step - loss: 0.4155 - acc: 0.8590 - val_loss: 0.6108 - val_acc: 0.8023
# Epoch 41/50
# 391/390 [==============================] - 50s 129ms/step - loss: 0.4147 - acc: 0.8602 - val_loss: 0.4912 - val_acc: 0.8376
# Epoch 42/50
# 391/390 [==============================] - 52s 132ms/step - loss: 0.4067 - acc: 0.8609 - val_loss: 0.6013 - val_acc: 0.8093
# Epoch 43/50
# 391/390 [==============================] - 50s 128ms/step - loss: 0.4052 - acc: 0.8617 - val_loss: 0.5098 - val_acc: 0.8327
# Epoch 44/50
# 391/390 [==============================] - 50s 129ms/step - loss: 0.3969 - acc: 0.8651 - val_loss: 0.6006 - val_acc: 0.8171
# Epoch 45/50
# 391/390 [==============================] - 50s 129ms/step - loss: 0.3896 - acc: 0.8667 - val_loss: 0.5101 - val_acc: 0.8366
# Epoch 46/50
# 391/390 [==============================] - 49s 126ms/step - loss: 0.3852 - acc: 0.8693 - val_loss: 0.5270 - val_acc: 0.8331
# Epoch 47/50
# 391/390 [==============================] - 49s 126ms/step - loss: 0.3867 - acc: 0.8708 - val_loss: 0.4555 - val_acc: 0.8522
# Epoch 48/50
# 391/390 [==============================] - 50s 129ms/step - loss: 0.3773 - acc: 0.8714 - val_loss: 0.5982 - val_acc: 0.8061
# Epoch 49/50
# 391/390 [==============================] - 50s 127ms/step - loss: 0.3766 - acc: 0.8721 - val_loss: 0.5261 - val_acc: 0.8297
# Epoch 50/50
# 391/390 [==============================] - 48s 124ms/step - loss: 0.3815 - acc: 0.8701 - val_loss: 0.5494 - val_acc: 0.8224
